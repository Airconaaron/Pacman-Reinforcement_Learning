# %% [markdown]
# # Deep Q-learning
#
# In this notebook, we'll build a neural network that can learn to play games through reinforcement learning. More specifically, we'll use Q-learning to train an agent to play a game called [Cart-Pole](https://gym.openai.com/envs/CartPole-v0). In this game, a freely swinging pole is attached to a cart. The cart can move to the left and right, and the goal is to keep the pole upright as long as possible.
#
# ![Cart-Pole](assets/cart-pole.jpg)
#
# We can simulate this game using [OpenAI Gym](https://gym.openai.com/). First, let's check out how OpenAI Gym works. Then, we'll get into training an agent to play the Cart-Pole game.

# %%
import gym
import tensorflow as tf
import numpy as np

# %% [markdown]
# >**Note:** Make sure you have OpenAI Gym cloned into the same directory with this notebook. I've included `gym` as a submodule, so you can run `git submodule --init --recursive` to pull the contents into the `gym` repo.

# %%
# Create the Cart-Pole game environment
env = gym.make('CartPole-v0')
# Out:
# [2017-09-12 14:31:42,653] Making new env: CartPole-v0

# %% [markdown]
# We interact with the simulation through `env`. To show the simulation running, you can use `env.render()` to render one frame. Passing in an action as an integer to `env.step` will generate the next step in the simulation.  You can see how many actions are possible from `env.action_space` and to get a random action you can use `env.action_space.sample()`. This is general to all Gym games. In the Cart-Pole game, there are two possible actions, moving the cart left or right. So there are two actions we can take, encoded as 0 and 1.
#
# Run the code below to watch the simulation run.

# %%
env.reset()
rewards = []
for _ in range(100):
    env.render()
    state, reward, done, info = env.step(env.action_space.sample()) # take a random action
    rewards.append(reward)
    if done:
        rewards = []
        env.reset()

# %%
env.close()

# %% [markdown]
# To shut the window showing the simulation, use `env.close()`.

# %% [markdown]
# If you ran the simulation above, we can look at the rewards:

# %%
print(rewards[-20:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f6344eaeebcf> in <module>()
# ----> 1 print(rewards[-20:])
#
# NameError: name 'rewards' is not defined

# %% [markdown]
# The game resets after the pole has fallen past a certain angle. For each frame while the simulation is running, it returns a reward of 1.0. The longer the game runs, the more reward we get. Then, our network's goal is to maximize the reward by keeping the pole vertical. It will do this by moving the cart to the left and the right.

# %% [markdown]
# ## Q-Network
#
# We train our Q-learning agent using the Bellman Equation:
#
# $$
# Q(s, a) = r + \gamma \max{Q(s', a')}
# $$
#
# where $s$ is a state, $a$ is an action, and $s'$ is the next state from state $s$ and action $a$.
#
# Before we used this equation to learn values for a Q-_table_. However, for this game there are a huge number of states available. The state has four values: the position and velocity of the cart, and the position and velocity of the pole. These are all real-valued numbers, so ignoring floating point precisions, you practically have infinite states. Instead of using a table then, we'll replace it with a neural network that will approximate the Q-table lookup function.
#
# <img src="assets/deep-q-learning.png" width=450px>
#
# Now, our Q value, $Q(s, a)$ is calculated by passing in a state to the network. The output will be Q-values for each available action, with fully connected hidden layers.
#
# <img src="assets/q-network.png" width=550px>
#
#
# As I showed before, we can define our targets for training as $\hat{Q}(s,a) = r + \gamma \max{Q(s', a')}$. Then we update the weights by minimizing $(\hat{Q}(s,a) - Q(s,a))^2$.
#
# For this Cart-Pole game, we have four inputs, one for each value in the state, and two outputs, one for each action. To get $\hat{Q}$, we'll first choose an action, then simulate the game using that action. This will get us the next state, $s'$, and the reward. With that, we can calculate $\hat{Q}$ then pass it back into the $Q$ network to run the optimizer and update the weights.
#
# Below is my implementation of the Q-network. I used two fully connected layers with ReLU activations. Two seems to be good enough, three might be better. Feel free to try it out.

# %%
class QNetwork:
    def __init__(self, learning_rate=0.01, state_size=4, 
                 action_size=2, hidden_size=10, 
                 name='QNetwork'):
        # state inputs to the Q-network
        with tf.variable_scope(name):
            self.inputs_ = tf.placeholder(tf.float32, [None, state_size], name='inputs')
            
            # One hot encode the actions to later choose the Q-value for the action
            self.actions_ = tf.placeholder(tf.int32, [None], name='actions')
            one_hot_actions = tf.one_hot(self.actions_, action_size)
            
            # Target Q values for training
            self.targetQs_ = tf.placeholder(tf.float32, [None], name='target')
            
            # ReLU hidden layers
            self.fc1 = tf.contrib.layers.fully_connected(self.inputs_, hidden_size)
            self.fc2 = tf.contrib.layers.fully_connected(self.fc1, hidden_size)

            # Linear output layer
            self.output = tf.contrib.layers.fully_connected(self.fc2, action_size, 
                                                            activation_fn=None)
            
            ### Train with loss (targetQ - Q)^2
            # output has length 2, for two actions. This next line chooses
            # one value from output (per row) according to the one-hot encoded actions.
            self.Q = tf.reduce_sum(tf.multiply(self.output, one_hot_actions), axis=1)
            
            self.loss = tf.reduce_mean(tf.square(self.targetQs_ - self.Q))
            self.opt = tf.train.AdamOptimizer(learning_rate).minimize(self.loss)

# %% [markdown]
# ## Experience replay
#
# Reinforcement learning algorithms can have stability issues due to correlations between states. To reduce correlations when training, we can store the agent's experiences and later draw a random mini-batch of those experiences to train on.
#
# Here, we'll create a `Memory` object that will store our experiences, our transitions $<s, a, r, s'>$. This memory will have a maxmium capacity, so we can keep newer experiences in memory while getting rid of older experiences. Then, we'll sample a random mini-batch of transitions $<s, a, r, s'>$ and train on those.
#
# Below, I've implemented a `Memory` object. If you're unfamiliar with `deque`, this is a double-ended queue. You can think of it like a tube open on both sides. You can put objects in either side of the tube. But if it's full, adding anything more will push an object out the other side. This is a great data structure to use for the memory buffer.

# %%
from collections import deque
class Memory():
    def __init__(self, max_size = 1000):
        self.buffer = deque(maxlen=max_size)
    
    def add(self, experience):
        self.buffer.append(experience)
            
    def sample(self, batch_size):
        idx = np.random.choice(np.arange(len(self.buffer)), 
                               size=batch_size, 
                               replace=False)
        return [self.buffer[ii] for ii in idx]

# %% [markdown]
# ## Exploration - Exploitation
#
# To learn about the environment and rules of the game, the agent needs to explore by taking random actions. We'll do this by choosing a random action with some probability $\epsilon$ (epsilon).  That is, with some probability $\epsilon$ the agent will make a random action and with probability $1 - \epsilon$, the agent will choose an action from $Q(s,a)$. This is called an **$\epsilon$-greedy policy**.
#
#
# At first, the agent needs to do a lot of exploring. Later when it has learned more, the agent can favor choosing actions based on what it has learned. This is called _exploitation_. We'll set it up so the agent is more likely to explore early in training, then more likely to exploit later in training.

# %% [markdown]
# ## Q-Learning training algorithm
#
# Putting all this together, we can list out the algorithm we'll use to train the network. We'll train the network in _episodes_. One *episode* is one simulation of the game. For this game, the goal is to keep the pole upright for 195 frames. So we can start a new episode once meeting that goal. The game ends if the pole tilts over too far, or if the cart moves too far the left or right. When a game ends, we'll start a new episode. Now, to train the agent:
#
# * Initialize the memory $D$
# * Initialize the action-value network $Q$ with random weights
# * **For** episode = 1, $M$ **do**
#   * **For** $t$, $T$ **do**
#      * With probability $\epsilon$ select a random action $a_t$, otherwise select $a_t = \mathrm{argmax}_a Q(s,a)$
#      * Execute action $a_t$ in simulator and observe reward $r_{t+1}$ and new state $s_{t+1}$
#      * Store transition $<s_t, a_t, r_{t+1}, s_{t+1}>$ in memory $D$
#      * Sample random mini-batch from $D$: $<s_j, a_j, r_j, s'_j>$
#      * Set $\hat{Q}_j = r_j$ if the episode ends at $j+1$, otherwise set $\hat{Q}_j = r_j + \gamma \max_{a'}{Q(s'_j, a')}$
#      * Make a gradient descent step with loss $(\hat{Q}_j - Q(s_j, a_j))^2$
#   * **endfor**
# * **endfor**

# %% [markdown]
# ## Hyperparameters
#
# One of the more difficult aspects of reinforcememt learning are the large number of hyperparameters. Not only are we tuning the network, but we're tuning the simulation.

# %%
train_episodes = 1000          # max number of episodes to learn from
max_steps = 200                # max steps in an episode
gamma = 0.99                   # future reward discount

# Exploration parameters
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01            # minimum exploration probability 
decay_rate = 0.0001            # exponential decay rate for exploration prob

# Network parameters
hidden_size = 64               # number of units in each Q-network hidden layer
learning_rate = 0.0001         # Q-network learning rate

# Memory parameters
memory_size = 10000            # memory capacity
batch_size = 20                # experience mini-batch size
pretrain_length = batch_size   # number experiences to pretrain the memory

# %%
tf.reset_default_graph()
mainQN = QNetwork(name='main', hidden_size=hidden_size, learning_rate=learning_rate)

# %% [markdown]
# ## Populate the experience memory
#
# Here I'm re-initializing the simulation and pre-populating the memory. The agent is taking random actions and storing the transitions in memory. This will help the agent with exploring the game.

# %%
# Initialize the simulation
env.reset()
# Take one random step to get the pole and cart moving
state, reward, done, _ = env.step(env.action_space.sample())

memory = Memory(max_size=memory_size)

# Make a bunch of random actions and store the experiences
for ii in range(pretrain_length):
    # Uncomment the line below to watch the simulation
    # env.render()

    # Make a random action
    action = env.action_space.sample()
    next_state, reward, done, _ = env.step(action)

    if done:
        # The simulation fails so no next state
        next_state = np.zeros(state.shape)
        # Add experience to memory
        memory.add((state, action, reward, next_state))
        
        # Start new episode
        env.reset()
        # Take one random step to get the pole and cart moving
        state, reward, done, _ = env.step(env.action_space.sample())
    else:
        # Add experience to memory
        memory.add((state, action, reward, next_state))
        state = next_state

# %% [markdown]
# ## Training
#
# Below we'll train our agent. If you want to watch it train, uncomment the `env.render()` line. This is slow because it's rendering the frames slower than the network can train. But, it's cool to watch the agent get better at the game.

# %%
# Now train with experiences
saver = tf.train.Saver()
rewards_list = []
with tf.Session() as sess:
    # Initialize variables
    sess.run(tf.global_variables_initializer())
    
    step = 0
    for ep in range(1, train_episodes):
        total_reward = 0
        t = 0
        while t < max_steps:
            step += 1
            # Uncomment this next line to watch the training
            env.render() 
            
            # Explore or Exploit
            explore_p = explore_stop + (explore_start - explore_stop)*np.exp(-decay_rate*step) 
            if explore_p > np.random.rand():
                # Make a random action
                action = env.action_space.sample()
            else:
                # Get action from Q-network
                feed = {mainQN.inputs_: state.reshape((1, *state.shape))}
                Qs = sess.run(mainQN.output, feed_dict=feed)
                action = np.argmax(Qs)
            
            # Take action, get new state and reward
            next_state, reward, done, _ = env.step(action)
    
            total_reward += reward
            
            if done:
                # the episode ends so no next state
                next_state = np.zeros(state.shape)
                t = max_steps
                
                print('Episode: {}'.format(ep),
                      'Total reward: {}'.format(total_reward),
                      'Training loss: {:.4f}'.format(loss),
                      'Explore P: {:.4f}'.format(explore_p))
                rewards_list.append((ep, total_reward))
                
                # Add experience to memory
                memory.add((state, action, reward, next_state))
                
                # Start new episode
                env.reset()
                # Take one random step to get the pole and cart moving
                state, reward, done, _ = env.step(env.action_space.sample())

            else:
                # Add experience to memory
                memory.add((state, action, reward, next_state))
                state = next_state
                t += 1
            
            # Sample mini-batch from memory
            batch = memory.sample(batch_size)
            states = np.array([each[0] for each in batch])
            actions = np.array([each[1] for each in batch])
            rewards = np.array([each[2] for each in batch])
            next_states = np.array([each[3] for each in batch])
            
            # Train network
            target_Qs = sess.run(mainQN.output, feed_dict={mainQN.inputs_: next_states})
            
            # Set target_Qs to 0 for states where episode ends
            episode_ends = (next_states == np.zeros(states[0].shape)).all(axis=1)
            target_Qs[episode_ends] = (0, 0)
            
            targets = rewards + gamma * np.max(target_Qs, axis=1)

            loss, _ = sess.run([mainQN.loss, mainQN.opt],
                                feed_dict={mainQN.inputs_: states,
                                           mainQN.targetQs_: targets,
                                           mainQN.actions_: actions})
        
    saver.save(sess, "checkpoints/cartpole.ckpt")
# Out:
# Episode: 1 Total reward: 5.0 Training loss: 1.1135 Explore P: 0.9995
# Episode: 2 Total reward: 19.0 Training loss: 1.0469 Explore P: 0.9976
# Episode: 3 Total reward: 16.0 Training loss: 0.9867 Explore P: 0.9960
# Episode: 4 Total reward: 17.0 Training loss: 0.9942 Explore P: 0.9944
# Episode: 5 Total reward: 11.0 Training loss: 1.1122 Explore P: 0.9933
# Episode: 6 Total reward: 20.0 Training loss: 1.0318 Explore P: 0.9913
# Episode: 7 Total reward: 14.0 Training loss: 1.1660 Explore P: 0.9900
# Episode: 8 Total reward: 40.0 Training loss: 1.0401 Explore P: 0.9860
# Episode: 9 Total reward: 21.0 Training loss: 1.0544 Explore P: 0.9840
# Episode: 10 Total reward: 18.0 Training loss: 1.1086 Explore P: 0.9822
# Episode: 11 Total reward: 18.0 Training loss: 1.0341 Explore P: 0.9805
# Episode: 12 Total reward: 18.0 Training loss: 1.2568 Explore P: 0.9787
# Episode: 13 Total reward: 30.0 Training loss: 1.2591 Explore P: 0.9758
# Episode: 14 Total reward: 31.0 Training loss: 1.2429 Explore P: 0.9729
# Episode: 15 Total reward: 11.0 Training loss: 1.2713 Explore P: 0.9718
# Episode: 16 Total reward: 20.0 Training loss: 1.2872 Explore P: 0.9699
# Episode: 17 Total reward: 25.0 Training loss: 1.7295 Explore P: 0.9675
# Episode: 18 Total reward: 28.0 Training loss: 1.3458 Explore P: 0.9648
# Episode: 19 Total reward: 15.0 Training loss: 2.1950 Explore P: 0.9634
# Episode: 20 Total reward: 10.0 Training loss: 1.7199 Explore P: 0.9624
# Episode: 21 Total reward: 15.0 Training loss: 2.6349 Explore P: 0.9610
# Episode: 22 Total reward: 24.0 Training loss: 1.9690 Explore P: 0.9587
# Episode: 23 Total reward: 9.0 Training loss: 2.7537 Explore P: 0.9579
# Episode: 24 Total reward: 12.0 Training loss: 2.3463 Explore P: 0.9567
# Episode: 25 Total reward: 17.0 Training loss: 5.2483 Explore P: 0.9551
# Episode: 26 Total reward: 27.0 Training loss: 3.2285 Explore P: 0.9526
# Episode: 27 Total reward: 50.0 Training loss: 3.1694 Explore P: 0.9479
# Episode: 28 Total reward: 16.0 Training loss: 5.9571 Explore P: 0.9464
# Episode: 29 Total reward: 12.0 Training loss: 5.1244 Explore P: 0.9452
# Episode: 30 Total reward: 26.0 Training loss: 3.5526 Explore P: 0.9428
# Episode: 31 Total reward: 14.0 Training loss: 9.0665 Explore P: 0.9415
# Episode: 32 Total reward: 11.0 Training loss: 9.8520 Explore P: 0.9405
# Episode: 33 Total reward: 16.0 Training loss: 2.5396 Explore P: 0.9390
# Episode: 34 Total reward: 12.0 Training loss: 2.8262 Explore P: 0.9379
# Episode: 35 Total reward: 25.0 Training loss: 6.0055 Explore P: 0.9356
# Episode: 36 Total reward: 11.0 Training loss: 9.9105 Explore P: 0.9345
# Episode: 37 Total reward: 16.0 Training loss: 7.2444 Explore P: 0.9331
# Episode: 38 Total reward: 24.0 Training loss: 3.6672 Explore P: 0.9309
# Episode: 39 Total reward: 14.0 Training loss: 4.9742 Explore P: 0.9296
# Episode: 40 Total reward: 22.0 Training loss: 3.3407 Explore P: 0.9275
# Episode: 41 Total reward: 13.0 Training loss: 3.8486 Explore P: 0.9264
# Episode: 42 Total reward: 27.0 Training loss: 4.8694 Explore P: 0.9239
# Episode: 43 Total reward: 9.0 Training loss: 7.4307 Explore P: 0.9231
# Episode: 44 Total reward: 11.0 Training loss: 32.7631 Explore P: 0.9221
# Episode: 45 Total reward: 36.0 Training loss: 32.4630 Explore P: 0.9188
# Episode: 46 Total reward: 31.0 Training loss: 20.8429 Explore P: 0.9160
# Episode: 47 Total reward: 10.0 Training loss: 4.1655 Explore P: 0.9151
# Episode: 48 Total reward: 15.0 Training loss: 4.4446 Explore P: 0.9137
# Episode: 49 Total reward: 31.0 Training loss: 26.4540 Explore P: 0.9109
# Episode: 50 Total reward: 26.0 Training loss: 9.0251 Explore P: 0.9086
# Episode: 51 Total reward: 10.0 Training loss: 28.3238 Explore P: 0.9077
# Episode: 52 Total reward: 14.0 Training loss: 5.0416 Explore P: 0.9064
# Episode: 53 Total reward: 13.0 Training loss: 3.5019 Explore P: 0.9053
# Episode: 54 Total reward: 20.0 Training loss: 10.5312 Explore P: 0.9035
# Episode: 55 Total reward: 15.0 Training loss: 10.9353 Explore P: 0.9021
# Episode: 56 Total reward: 13.0 Training loss: 5.8705 Explore P: 0.9010
# Episode: 57 Total reward: 19.0 Training loss: 53.5708 Explore P: 0.8993
# Episode: 58 Total reward: 34.0 Training loss: 49.0695 Explore P: 0.8963
# Episode: 59 Total reward: 14.0 Training loss: 17.4837 Explore P: 0.8950
# Episode: 60 Total reward: 16.0 Training loss: 16.3644 Explore P: 0.8936
# Episode: 61 Total reward: 33.0 Training loss: 5.5948 Explore P: 0.8907
# Episode: 62 Total reward: 17.0 Training loss: 4.1340 Explore P: 0.8892
# Episode: 63 Total reward: 15.0 Training loss: 5.4491 Explore P: 0.8879
# Episode: 64 Total reward: 32.0 Training loss: 36.8293 Explore P: 0.8851
# Episode: 65 Total reward: 14.0 Training loss: 19.7579 Explore P: 0.8838
# Episode: 66 Total reward: 8.0 Training loss: 38.8983 Explore P: 0.8831
# Episode: 67 Total reward: 12.0 Training loss: 37.9880 Explore P: 0.8821
# Episode: 68 Total reward: 46.0 Training loss: 15.7353 Explore P: 0.8781
# Episode: 69 Total reward: 41.0 Training loss: 60.4021 Explore P: 0.8745
# Episode: 70 Total reward: 16.0 Training loss: 33.3378 Explore P: 0.8732
# Episode: 71 Total reward: 12.0 Training loss: 65.3904 Explore P: 0.8721
# Episode: 72 Total reward: 11.0 Training loss: 67.4169 Explore P: 0.8712
# Episode: 73 Total reward: 15.0 Training loss: 34.7701 Explore P: 0.8699
# Episode: 74 Total reward: 12.0 Training loss: 14.2784 Explore P: 0.8689
# Episode: 75 Total reward: 17.0 Training loss: 40.2716 Explore P: 0.8674
# Episode: 76 Total reward: 37.0 Training loss: 52.9214 Explore P: 0.8642
# Episode: 77 Total reward: 19.0 Training loss: 4.9850 Explore P: 0.8626
# Episode: 78 Total reward: 35.0 Training loss: 21.9255 Explore P: 0.8596
# Episode: 79 Total reward: 38.0 Training loss: 100.1122 Explore P: 0.8564
# Episode: 80 Total reward: 11.0 Training loss: 52.6482 Explore P: 0.8555
# Episode: 81 Total reward: 27.0 Training loss: 22.5384 Explore P: 0.8532
# Episode: 82 Total reward: 10.0 Training loss: 90.1052 Explore P: 0.8524
# Episode: 83 Total reward: 12.0 Training loss: 49.3395 Explore P: 0.8513
# Episode: 84 Total reward: 30.0 Training loss: 57.6037 Explore P: 0.8488
# Episode: 85 Total reward: 26.0 Training loss: 37.1015 Explore P: 0.8466
# Episode: 86 Total reward: 41.0 Training loss: 37.5723 Explore P: 0.8432
# Episode: 87 Total reward: 40.0 Training loss: 24.6072 Explore P: 0.8399
# Episode: 88 Total reward: 32.0 Training loss: 4.1799 Explore P: 0.8372
# Episode: 89 Total reward: 42.0 Training loss: 3.8772 Explore P: 0.8338
# Episode: 90 Total reward: 9.0 Training loss: 28.6997 Explore P: 0.8330
# Episode: 91 Total reward: 43.0 Training loss: 4.2603 Explore P: 0.8295
# Episode: 92 Total reward: 12.0 Training loss: 128.7484 Explore P: 0.8285
# Episode: 93 Total reward: 11.0 Training loss: 44.2926 Explore P: 0.8276
# Episode: 94 Total reward: 12.0 Training loss: 46.4630 Explore P: 0.8266
# Episode: 95 Total reward: 12.0 Training loss: 34.9408 Explore P: 0.8257
# Episode: 96 Total reward: 28.0 Training loss: 3.3755 Explore P: 0.8234
# Episode: 97 Total reward: 86.0 Training loss: 3.0469 Explore P: 0.8164
# Episode: 98 Total reward: 18.0 Training loss: 79.0495 Explore P: 0.8150
# Episode: 99 Total reward: 12.0 Training loss: 133.3604 Explore P: 0.8140
# Episode: 100 Total reward: 21.0 Training loss: 3.0632 Explore P: 0.8123
# Episode: 101 Total reward: 22.0 Training loss: 65.0454 Explore P: 0.8106
# Episode: 102 Total reward: 38.0 Training loss: 114.5933 Explore P: 0.8075
# Episode: 103 Total reward: 11.0 Training loss: 1.4899 Explore P: 0.8066
# Episode: 104 Total reward: 24.0 Training loss: 2.5832 Explore P: 0.8047
# Episode: 105 Total reward: 15.0 Training loss: 1.6163 Explore P: 0.8035
# Episode: 106 Total reward: 11.0 Training loss: 39.9080 Explore P: 0.8027
# Episode: 107 Total reward: 22.0 Training loss: 62.3060 Explore P: 0.8009
# Episode: 108 Total reward: 17.0 Training loss: 1.5050 Explore P: 0.7996
# Episode: 109 Total reward: 10.0 Training loss: 80.6076 Explore P: 0.7988
# Episode: 110 Total reward: 22.0 Training loss: 29.4337 Explore P: 0.7971
# Episode: 111 Total reward: 15.0 Training loss: 94.2126 Explore P: 0.7959
# Episode: 112 Total reward: 22.0 Training loss: 25.4378 Explore P: 0.7942
# Episode: 113 Total reward: 18.0 Training loss: 87.9994 Explore P: 0.7927
# Episode: 114 Total reward: 14.0 Training loss: 56.0689 Explore P: 0.7916
# Episode: 115 Total reward: 19.0 Training loss: 93.4653 Explore P: 0.7902
# Episode: 116 Total reward: 19.0 Training loss: 53.0275 Explore P: 0.7887
# Episode: 117 Total reward: 17.0 Training loss: 0.9808 Explore P: 0.7874
# Episode: 118 Total reward: 9.0 Training loss: 28.3738 Explore P: 0.7867
# Episode: 119 Total reward: 8.0 Training loss: 1.4699 Explore P: 0.7860
# Episode: 120 Total reward: 11.0 Training loss: 1.1479 Explore P: 0.7852
# Episode: 121 Total reward: 12.0 Training loss: 78.0813 Explore P: 0.7843
# Episode: 122 Total reward: 16.0 Training loss: 85.3888 Explore P: 0.7830
# Episode: 123 Total reward: 11.0 Training loss: 23.4610 Explore P: 0.7822
# Episode: 124 Total reward: 12.0 Training loss: 1.7128 Explore P: 0.7812
# Episode: 125 Total reward: 10.0 Training loss: 53.8748 Explore P: 0.7805
# Episode: 126 Total reward: 9.0 Training loss: 0.7206 Explore P: 0.7798
# Episode: 127 Total reward: 13.0 Training loss: 42.5871 Explore P: 0.7788
# Episode: 128 Total reward: 13.0 Training loss: 87.4049 Explore P: 0.7778
# Episode: 129 Total reward: 8.0 Training loss: 1.3326 Explore P: 0.7772
# Episode: 130 Total reward: 9.0 Training loss: 1.1823 Explore P: 0.7765
# Episode: 131 Total reward: 13.0 Training loss: 23.0877 Explore P: 0.7755
# Episode: 132 Total reward: 14.0 Training loss: 61.6805 Explore P: 0.7744
# Episode: 133 Total reward: 14.0 Training loss: 24.0416 Explore P: 0.7733
# Episode: 134 Total reward: 12.0 Training loss: 1.2429 Explore P: 0.7724
# Episode: 135 Total reward: 21.0 Training loss: 19.1593 Explore P: 0.7708
# Episode: 136 Total reward: 18.0 Training loss: 75.3962 Explore P: 0.7695
# Episode: 137 Total reward: 14.0 Training loss: 1.2113 Explore P: 0.7684
# Episode: 138 Total reward: 57.0 Training loss: 1.2131 Explore P: 0.7641
# Episode: 139 Total reward: 11.0 Training loss: 1.5932 Explore P: 0.7633
# Episode: 140 Total reward: 15.0 Training loss: 1.5978 Explore P: 0.7621
# Episode: 141 Total reward: 11.0 Training loss: 40.5025 Explore P: 0.7613
# Episode: 142 Total reward: 15.0 Training loss: 72.5052 Explore P: 0.7602
# Episode: 143 Total reward: 8.0 Training loss: 23.2750 Explore P: 0.7596
# Episode: 144 Total reward: 21.0 Training loss: 20.7752 Explore P: 0.7580
# Episode: 145 Total reward: 15.0 Training loss: 36.7589 Explore P: 0.7569
# Episode: 146 Total reward: 19.0 Training loss: 1.6520 Explore P: 0.7555
# Episode: 147 Total reward: 14.0 Training loss: 29.4250 Explore P: 0.7544
# Episode: 148 Total reward: 23.0 Training loss: 75.3529 Explore P: 0.7527
# Episode: 149 Total reward: 16.0 Training loss: 58.8462 Explore P: 0.7515
# Episode: 150 Total reward: 18.0 Training loss: 1.9167 Explore P: 0.7502
# Episode: 151 Total reward: 16.0 Training loss: 17.6803 Explore P: 0.7490
# Episode: 152 Total reward: 17.0 Training loss: 21.5109 Explore P: 0.7477
# Episode: 153 Total reward: 13.0 Training loss: 19.5638 Explore P: 0.7468
# Episode: 154 Total reward: 22.0 Training loss: 20.1236 Explore P: 0.7452
# Episode: 155 Total reward: 11.0 Training loss: 77.8483 Explore P: 0.7444
# Episode: 156 Total reward: 21.0 Training loss: 44.8093 Explore P: 0.7428
# Episode: 157 Total reward: 15.0 Training loss: 38.7777 Explore P: 0.7417
# Episode: 158 Total reward: 21.0 Training loss: 21.9319 Explore P: 0.7402
# Episode: 159 Total reward: 15.0 Training loss: 2.4389 Explore P: 0.7391
# Episode: 160 Total reward: 19.0 Training loss: 39.7182 Explore P: 0.7377
# Episode: 161 Total reward: 23.0 Training loss: 1.9047 Explore P: 0.7360
# Episode: 162 Total reward: 11.0 Training loss: 20.8252 Explore P: 0.7352
# Episode: 163 Total reward: 15.0 Training loss: 59.0132 Explore P: 0.7342
# Episode: 164 Total reward: 12.0 Training loss: 2.0644 Explore P: 0.7333
# Episode: 165 Total reward: 15.0 Training loss: 17.6074 Explore P: 0.7322
# Episode: 166 Total reward: 74.0 Training loss: 20.8284 Explore P: 0.7269
# Episode: 167 Total reward: 14.0 Training loss: 1.5734 Explore P: 0.7259
# Episode: 168 Total reward: 20.0 Training loss: 1.5810 Explore P: 0.7244
# Episode: 169 Total reward: 39.0 Training loss: 70.5313 Explore P: 0.7217
# Episode: 170 Total reward: 10.0 Training loss: 1.6514 Explore P: 0.7210
# Episode: 171 Total reward: 10.0 Training loss: 1.7757 Explore P: 0.7202
# Episode: 172 Total reward: 18.0 Training loss: 16.6155 Explore P: 0.7190
# Episode: 173 Total reward: 11.0 Training loss: 16.6054 Explore P: 0.7182
# Episode: 174 Total reward: 14.0 Training loss: 72.1413 Explore P: 0.7172
# Episode: 175 Total reward: 11.0 Training loss: 40.4051 Explore P: 0.7164
# Episode: 176 Total reward: 12.0 Training loss: 57.5355 Explore P: 0.7156
# Episode: 177 Total reward: 15.0 Training loss: 1.7269 Explore P: 0.7145
# Episode: 178 Total reward: 16.0 Training loss: 17.4474 Explore P: 0.7134
# Episode: 179 Total reward: 10.0 Training loss: 60.1354 Explore P: 0.7127
# Episode: 180 Total reward: 21.0 Training loss: 1.5862 Explore P: 0.7112
# Episode: 181 Total reward: 31.0 Training loss: 56.2704 Explore P: 0.7090
# Episode: 182 Total reward: 28.0 Training loss: 32.8521 Explore P: 0.7071
# Episode: 183 Total reward: 12.0 Training loss: 1.7133 Explore P: 0.7062
# Episode: 184 Total reward: 37.0 Training loss: 1.7937 Explore P: 0.7037
# Episode: 185 Total reward: 14.0 Training loss: 52.2032 Explore P: 0.7027
# Episode: 186 Total reward: 10.0 Training loss: 30.0956 Explore P: 0.7020
# Episode: 187 Total reward: 10.0 Training loss: 45.1228 Explore P: 0.7013
# Episode: 188 Total reward: 29.0 Training loss: 36.3887 Explore P: 0.6993
# Episode: 189 Total reward: 11.0 Training loss: 32.2396 Explore P: 0.6986
# Episode: 190 Total reward: 12.0 Training loss: 1.4191 Explore P: 0.6977
# Episode: 191 Total reward: 9.0 Training loss: 19.2088 Explore P: 0.6971
# Episode: 192 Total reward: 15.0 Training loss: 37.3820 Explore P: 0.6961
# Episode: 193 Total reward: 14.0 Training loss: 42.6056 Explore P: 0.6951
# Episode: 194 Total reward: 15.0 Training loss: 18.6653 Explore P: 0.6941
# Episode: 195 Total reward: 21.0 Training loss: 1.4376 Explore P: 0.6927
# Episode: 196 Total reward: 11.0 Training loss: 1.6606 Explore P: 0.6919
# Episode: 197 Total reward: 10.0 Training loss: 32.2514 Explore P: 0.6912
# Episode: 198 Total reward: 14.0 Training loss: 50.1935 Explore P: 0.6903
# Episode: 199 Total reward: 17.0 Training loss: 18.6795 Explore P: 0.6891
# Episode: 200 Total reward: 13.0 Training loss: 1.6508 Explore P: 0.6882
# Episode: 201 Total reward: 10.0 Training loss: 1.2041 Explore P: 0.6876
# Episode: 202 Total reward: 9.0 Training loss: 1.4620 Explore P: 0.6870
# Episode: 203 Total reward: 18.0 Training loss: 29.1202 Explore P: 0.6857
# Episode: 204 Total reward: 15.0 Training loss: 28.4505 Explore P: 0.6847
# Episode: 205 Total reward: 52.0 Training loss: 78.8927 Explore P: 0.6812
# Episode: 206 Total reward: 13.0 Training loss: 68.9032 Explore P: 0.6804
# Episode: 207 Total reward: 14.0 Training loss: 36.5976 Explore P: 0.6794
# Episode: 208 Total reward: 14.0 Training loss: 0.8633 Explore P: 0.6785
# Episode: 209 Total reward: 32.0 Training loss: 0.7632 Explore P: 0.6763
# Episode: 210 Total reward: 10.0 Training loss: 59.6192 Explore P: 0.6757
# Episode: 211 Total reward: 15.0 Training loss: 1.0048 Explore P: 0.6747
# Episode: 212 Total reward: 34.0 Training loss: 15.5524 Explore P: 0.6724
# Episode: 213 Total reward: 19.0 Training loss: 89.9568 Explore P: 0.6712
# Episode: 214 Total reward: 18.0 Training loss: 18.0470 Explore P: 0.6700
# Episode: 215 Total reward: 15.0 Training loss: 0.6492 Explore P: 0.6690
# Episode: 216 Total reward: 28.0 Training loss: 40.2396 Explore P: 0.6671
# Episode: 217 Total reward: 9.0 Training loss: 15.8342 Explore P: 0.6666
# Episode: 218 Total reward: 19.0 Training loss: 0.6549 Explore P: 0.6653
# Episode: 219 Total reward: 36.0 Training loss: 0.7956 Explore P: 0.6630
# Episode: 220 Total reward: 50.0 Training loss: 0.6843 Explore P: 0.6597
# Episode: 221 Total reward: 17.0 Training loss: 19.3502 Explore P: 0.6586
# Episode: 222 Total reward: 37.0 Training loss: 18.4212 Explore P: 0.6562
# Episode: 223 Total reward: 25.0 Training loss: 31.1406 Explore P: 0.6546
# Episode: 224 Total reward: 24.0 Training loss: 0.7038 Explore P: 0.6530
# Episode: 225 Total reward: 48.0 Training loss: 24.5643 Explore P: 0.6500
# Episode: 226 Total reward: 29.0 Training loss: 47.1199 Explore P: 0.6481
# Episode: 227 Total reward: 71.0 Training loss: 1.0754 Explore P: 0.6436
# Episode: 228 Total reward: 11.0 Training loss: 13.6922 Explore P: 0.6429
# Episode: 229 Total reward: 29.0 Training loss: 0.9098 Explore P: 0.6411
# Episode: 230 Total reward: 35.0 Training loss: 0.9095 Explore P: 0.6389
# Episode: 231 Total reward: 50.0 Training loss: 16.0957 Explore P: 0.6357
# Episode: 232 Total reward: 99.0 Training loss: 26.9346 Explore P: 0.6296
# Episode: 233 Total reward: 57.0 Training loss: 0.8806 Explore P: 0.6260
# Episode: 234 Total reward: 18.0 Training loss: 0.8269 Explore P: 0.6249
# Episode: 235 Total reward: 74.0 Training loss: 0.9112 Explore P: 0.6204
# Episode: 236 Total reward: 68.0 Training loss: 0.9322 Explore P: 0.6163
# Episode: 237 Total reward: 43.0 Training loss: 12.0461 Explore P: 0.6137
# Episode: 238 Total reward: 81.0 Training loss: 31.4040 Explore P: 0.6088
# Episode: 239 Total reward: 24.0 Training loss: 23.3348 Explore P: 0.6074
# Episode: 240 Total reward: 24.0 Training loss: 1.0206 Explore P: 0.6059
# Episode: 241 Total reward: 15.0 Training loss: 15.0853 Explore P: 0.6050
# Episode: 242 Total reward: 23.0 Training loss: 38.9416 Explore P: 0.6037
# Episode: 243 Total reward: 23.0 Training loss: 14.0702 Explore P: 0.6023
# Episode: 244 Total reward: 20.0 Training loss: 1.0021 Explore P: 0.6011
# Episode: 245 Total reward: 16.0 Training loss: 12.2022 Explore P: 0.6002
# Episode: 246 Total reward: 19.0 Training loss: 1.0435 Explore P: 0.5990
# Episode: 247 Total reward: 13.0 Training loss: 40.4388 Explore P: 0.5983
# Episode: 248 Total reward: 23.0 Training loss: 1.0815 Explore P: 0.5969
# Episode: 249 Total reward: 31.0 Training loss: 1.1641 Explore P: 0.5951
# Episode: 250 Total reward: 23.0 Training loss: 0.9003 Explore P: 0.5938
# Episode: 251 Total reward: 17.0 Training loss: 27.7752 Explore P: 0.5928
# Episode: 252 Total reward: 16.0 Training loss: 0.8877 Explore P: 0.5918
# Episode: 253 Total reward: 14.0 Training loss: 14.8302 Explore P: 0.5910
# Episode: 254 Total reward: 28.0 Training loss: 19.4606 Explore P: 0.5894
# Episode: 255 Total reward: 20.0 Training loss: 13.2488 Explore P: 0.5882
# Episode: 256 Total reward: 18.0 Training loss: 24.4358 Explore P: 0.5872
# Episode: 257 Total reward: 16.0 Training loss: 1.2232 Explore P: 0.5863
# Episode: 258 Total reward: 22.0 Training loss: 13.5509 Explore P: 0.5850
# Episode: 259 Total reward: 21.0 Training loss: 28.0917 Explore P: 0.5838
# Episode: 260 Total reward: 22.0 Training loss: 28.9177 Explore P: 0.5826
# Episode: 261 Total reward: 44.0 Training loss: 0.9377 Explore P: 0.5800
# Episode: 262 Total reward: 83.0 Training loss: 1.0211 Explore P: 0.5753
# Episode: 263 Total reward: 42.0 Training loss: 13.8436 Explore P: 0.5730
# Episode: 264 Total reward: 18.0 Training loss: 17.2339 Explore P: 0.5719
# Episode: 265 Total reward: 19.0 Training loss: 16.6741 Explore P: 0.5709
# Episode: 266 Total reward: 34.0 Training loss: 42.9108 Explore P: 0.5690
# Episode: 267 Total reward: 32.0 Training loss: 1.0328 Explore P: 0.5672
# Episode: 268 Total reward: 62.0 Training loss: 0.6322 Explore P: 0.5637
# Episode: 269 Total reward: 57.0 Training loss: 1.0425 Explore P: 0.5606
# Episode: 270 Total reward: 58.0 Training loss: 34.8877 Explore P: 0.5574
# Episode: 271 Total reward: 50.0 Training loss: 1.2829 Explore P: 0.5547
# Episode: 272 Total reward: 22.0 Training loss: 44.1177 Explore P: 0.5535
# Episode: 273 Total reward: 66.0 Training loss: 0.9675 Explore P: 0.5499
# Episode: 274 Total reward: 32.0 Training loss: 1.1746 Explore P: 0.5482
# Episode: 275 Total reward: 18.0 Training loss: 1.1780 Explore P: 0.5472
# Episode: 276 Total reward: 120.0 Training loss: 19.9839 Explore P: 0.5408
# Episode: 277 Total reward: 63.0 Training loss: 25.9887 Explore P: 0.5375
# Episode: 278 Total reward: 87.0 Training loss: 13.7030 Explore P: 0.5329
# Episode: 279 Total reward: 59.0 Training loss: 16.7966 Explore P: 0.5298
# Episode: 280 Total reward: 74.0 Training loss: 1.0362 Explore P: 0.5260
# Episode: 281 Total reward: 31.0 Training loss: 33.3587 Explore P: 0.5244
# Episode: 282 Total reward: 24.0 Training loss: 16.3720 Explore P: 0.5232
# Episode: 283 Total reward: 30.0 Training loss: 25.6119 Explore P: 0.5216
# Episode: 284 Total reward: 21.0 Training loss: 12.7965 Explore P: 0.5206
# Episode: 285 Total reward: 20.0 Training loss: 67.9830 Explore P: 0.5195
# Episode: 286 Total reward: 60.0 Training loss: 1.6650 Explore P: 0.5165
# Episode: 287 Total reward: 92.0 Training loss: 20.6553 Explore P: 0.5119
# Episode: 288 Total reward: 54.0 Training loss: 1.2518 Explore P: 0.5091
# Episode: 289 Total reward: 17.0 Training loss: 1.3696 Explore P: 0.5083
# Episode: 290 Total reward: 75.0 Training loss: 12.8616 Explore P: 0.5046
# Episode: 291 Total reward: 44.0 Training loss: 1.7323 Explore P: 0.5024
# Episode: 292 Total reward: 45.0 Training loss: 0.9569 Explore P: 0.5002
# Episode: 293 Total reward: 37.0 Training loss: 13.4833 Explore P: 0.4984
# Episode: 294 Total reward: 14.0 Training loss: 14.8676 Explore P: 0.4977
# Episode: 295 Total reward: 23.0 Training loss: 1.1391 Explore P: 0.4966
# Episode: 296 Total reward: 55.0 Training loss: 26.1906 Explore P: 0.4939
# Episode: 297 Total reward: 38.0 Training loss: 72.4363 Explore P: 0.4921
# Episode: 298 Total reward: 35.0 Training loss: 49.0798 Explore P: 0.4904
# Episode: 299 Total reward: 100.0 Training loss: 1.5414 Explore P: 0.4856
# Episode: 300 Total reward: 56.0 Training loss: 66.8442 Explore P: 0.4830
# Episode: 301 Total reward: 109.0 Training loss: 49.6279 Explore P: 0.4778
# Episode: 302 Total reward: 68.0 Training loss: 34.9066 Explore P: 0.4747
# Episode: 303 Total reward: 65.0 Training loss: 56.9847 Explore P: 0.4716
# Episode: 304 Total reward: 75.0 Training loss: 26.7449 Explore P: 0.4682
# Episode: 305 Total reward: 31.0 Training loss: 50.8275 Explore P: 0.4668
# Episode: 306 Total reward: 40.0 Training loss: 24.8033 Explore P: 0.4650
# Episode: 307 Total reward: 66.0 Training loss: 1.7454 Explore P: 0.4620
# Episode: 308 Total reward: 109.0 Training loss: 2.1917 Explore P: 0.4571
# Episode: 309 Total reward: 68.0 Training loss: 0.9941 Explore P: 0.4540
# Episode: 310 Total reward: 55.0 Training loss: 1.6395 Explore P: 0.4516
# Episode: 311 Total reward: 135.0 Training loss: 1.1570 Explore P: 0.4457
# Episode: 312 Total reward: 62.0 Training loss: 0.9965 Explore P: 0.4430
# Episode: 313 Total reward: 56.0 Training loss: 38.8352 Explore P: 0.4406
# Episode: 314 Total reward: 36.0 Training loss: 34.5867 Explore P: 0.4390
# Episode: 315 Total reward: 70.0 Training loss: 50.9113 Explore P: 0.4360
# Episode: 316 Total reward: 145.0 Training loss: 85.6069 Explore P: 0.4299
# Episode: 317 Total reward: 50.0 Training loss: 2.2769 Explore P: 0.4278
# Episode: 318 Total reward: 27.0 Training loss: 1.7176 Explore P: 0.4267
# Episode: 319 Total reward: 83.0 Training loss: 1.7466 Explore P: 0.4232
# Episode: 320 Total reward: 51.0 Training loss: 46.4260 Explore P: 0.4211
# Episode: 321 Total reward: 31.0 Training loss: 1.5277 Explore P: 0.4199
# Episode: 322 Total reward: 99.0 Training loss: 20.5415 Explore P: 0.4158
# Episode: 323 Total reward: 21.0 Training loss: 49.8342 Explore P: 0.4150
# Episode: 324 Total reward: 190.0 Training loss: 1.5660 Explore P: 0.4073
# Episode: 325 Total reward: 93.0 Training loss: 51.1021 Explore P: 0.4037
# Episode: 326 Total reward: 37.0 Training loss: 2.0783 Explore P: 0.4022
# Episode: 327 Total reward: 44.0 Training loss: 27.4150 Explore P: 0.4005
# Episode: 328 Total reward: 31.0 Training loss: 1.2908 Explore P: 0.3993
# Episode: 329 Total reward: 33.0 Training loss: 1.3743 Explore P: 0.3980
# Episode: 330 Total reward: 32.0 Training loss: 90.0787 Explore P: 0.3968
# Episode: 331 Total reward: 68.0 Training loss: 2.5739 Explore P: 0.3941
# Episode: 332 Total reward: 169.0 Training loss: 41.0620 Explore P: 0.3877
# Episode: 333 Total reward: 101.0 Training loss: 51.9687 Explore P: 0.3839
# Episode: 334 Total reward: 80.0 Training loss: 2.0961 Explore P: 0.3809
# Episode: 335 Total reward: 65.0 Training loss: 1.3380 Explore P: 0.3785
# Episode: 336 Total reward: 114.0 Training loss: 1.9196 Explore P: 0.3743
# Episode: 337 Total reward: 57.0 Training loss: 2.0645 Explore P: 0.3723
# Episode: 338 Total reward: 55.0 Training loss: 1.6788 Explore P: 0.3703
# Episode: 339 Total reward: 79.0 Training loss: 1.3417 Explore P: 0.3675
# Episode: 340 Total reward: 64.0 Training loss: 70.1281 Explore P: 0.3652
# Episode: 341 Total reward: 185.0 Training loss: 1.0922 Explore P: 0.3587
# Episode: 342 Total reward: 69.0 Training loss: 67.1897 Explore P: 0.3563
# Episode: 343 Total reward: 95.0 Training loss: 54.1397 Explore P: 0.3530
# Episode: 344 Total reward: 121.0 Training loss: 47.3858 Explore P: 0.3489
# Episode: 345 Total reward: 121.0 Training loss: 64.3302 Explore P: 0.3448
# Episode: 346 Total reward: 49.0 Training loss: 34.4985 Explore P: 0.3432
# Episode: 347 Total reward: 74.0 Training loss: 35.0932 Explore P: 0.3407
# Episode: 348 Total reward: 130.0 Training loss: 2.5263 Explore P: 0.3364
# Episode: 349 Total reward: 76.0 Training loss: 60.5445 Explore P: 0.3340
# Episode: 350 Total reward: 44.0 Training loss: 33.1582 Explore P: 0.3325
# Episode: 351 Total reward: 46.0 Training loss: 1.2880 Explore P: 0.3311
# Episode: 352 Total reward: 63.0 Training loss: 1.4582 Explore P: 0.3290
# Episode: 353 Total reward: 104.0 Training loss: 77.5228 Explore P: 0.3257
# Episode: 354 Total reward: 198.0 Training loss: 1.5249 Explore P: 0.3195
# Episode: 355 Total reward: 54.0 Training loss: 1.2237 Explore P: 0.3179
# Episode: 356 Total reward: 82.0 Training loss: 1.7854 Explore P: 0.3154
# Episode: 357 Total reward: 112.0 Training loss: 2.0025 Explore P: 0.3120
# Episode: 358 Total reward: 116.0 Training loss: 1.4570 Explore P: 0.3085
# Episode: 359 Total reward: 69.0 Training loss: 0.9450 Explore P: 0.3064
# Episode: 360 Total reward: 84.0 Training loss: 1.8019 Explore P: 0.3039
# Episode: 361 Total reward: 140.0 Training loss: 2.1334 Explore P: 0.2999
# Episode: 362 Total reward: 75.0 Training loss: 2.9094 Explore P: 0.2977
# Episode: 363 Total reward: 57.0 Training loss: 18.1824 Explore P: 0.2961
# Episode: 364 Total reward: 133.0 Training loss: 1.6073 Explore P: 0.2923
# Episode: 365 Total reward: 122.0 Training loss: 56.1993 Explore P: 0.2889
# Episode: 366 Total reward: 148.0 Training loss: 2.0079 Explore P: 0.2848
# Episode: 367 Total reward: 46.0 Training loss: 3.6002 Explore P: 0.2835
# Episode: 368 Total reward: 34.0 Training loss: 2.5416 Explore P: 0.2826
# Episode: 369 Total reward: 119.0 Training loss: 0.9749 Explore P: 0.2793
# Episode: 370 Total reward: 117.0 Training loss: 1.6382 Explore P: 0.2762
# Episode: 371 Total reward: 62.0 Training loss: 1.4070 Explore P: 0.2746
# Episode: 372 Total reward: 82.0 Training loss: 2.7600 Explore P: 0.2724
# Episode: 373 Total reward: 92.0 Training loss: 2.5500 Explore P: 0.2700
# Episode: 374 Total reward: 86.0 Training loss: 1.5967 Explore P: 0.2678
# Episode: 375 Total reward: 130.0 Training loss: 96.1389 Explore P: 0.2645
# Episode: 376 Total reward: 101.0 Training loss: 87.3475 Explore P: 0.2619
# Episode: 377 Total reward: 70.0 Training loss: 2.3725 Explore P: 0.2601
# Episode: 378 Total reward: 148.0 Training loss: 1.5031 Explore P: 0.2565
# Episode: 379 Total reward: 118.0 Training loss: 112.1792 Explore P: 0.2536
# Episode: 380 Total reward: 153.0 Training loss: 85.8152 Explore P: 0.2499
# Episode: 381 Total reward: 137.0 Training loss: 1.7995 Explore P: 0.2466
# Episode: 382 Total reward: 82.0 Training loss: 70.3034 Explore P: 0.2447
# Episode: 383 Total reward: 91.0 Training loss: 1.8676 Explore P: 0.2425
# Episode: 384 Total reward: 103.0 Training loss: 72.0954 Explore P: 0.2402
# Episode: 385 Total reward: 124.0 Training loss: 90.3143 Explore P: 0.2373
# Episode: 386 Total reward: 59.0 Training loss: 1.2550 Explore P: 0.2360
# Episode: 387 Total reward: 133.0 Training loss: 1.2349 Explore P: 0.2330
# Episode: 388 Total reward: 161.0 Training loss: 80.4714 Explore P: 0.2294
# Episode: 389 Total reward: 103.0 Training loss: 1.6743 Explore P: 0.2272
# Episode: 390 Total reward: 97.0 Training loss: 1.5255 Explore P: 0.2251
# Episode: 391 Total reward: 102.0 Training loss: 71.3923 Explore P: 0.2229
# Episode: 392 Total reward: 82.0 Training loss: 2.0358 Explore P: 0.2212
# Episode: 393 Total reward: 88.0 Training loss: 78.5940 Explore P: 0.2193
# Episode: 394 Total reward: 167.0 Training loss: 1.1797 Explore P: 0.2159
# Episode: 395 Total reward: 121.0 Training loss: 1.0248 Explore P: 0.2134
# Episode: 396 Total reward: 130.0 Training loss: 201.6953 Explore P: 0.2108
# Episode: 397 Total reward: 155.0 Training loss: 1.0410 Explore P: 0.2077
# Episode: 398 Total reward: 148.0 Training loss: 1.0987 Explore P: 0.2048
# Episode: 399 Total reward: 199.0 Training loss: 134.5375 Explore P: 0.2009
# Episode: 400 Total reward: 140.0 Training loss: 0.5533 Explore P: 0.1983
# Episode: 401 Total reward: 181.0 Training loss: 0.8945 Explore P: 0.1949
# Episode: 402 Total reward: 137.0 Training loss: 1.7010 Explore P: 0.1924
# Episode: 403 Total reward: 140.0 Training loss: 1.1660 Explore P: 0.1898
# Episode: 404 Total reward: 163.0 Training loss: 43.5393 Explore P: 0.1869

# %% [markdown]
# ## Visualizing training
#
# Below I'll plot the total rewards for each episode. I'm plotting the rolling average too, in blue.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
eps, rews = np.array(rewards_list).T
smoothed_rews = running_mean(rews, 10)
plt.plot(eps[-len(smoothed_rews):], smoothed_rews)
plt.plot(eps, rews, color='grey', alpha=0.3)
plt.xlabel('Episode')
plt.ylabel('Total Reward')

# %% [markdown]
# ## Testing
#
# Let's checkout how our trained agent plays the game.

# %%
test_episodes = 10
test_max_steps = 400
env.reset()
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    for ep in range(1, test_episodes):
        t = 0
        while t < test_max_steps:
            env.render() 
            
            # Get action from Q-network
            feed = {mainQN.inputs_: state.reshape((1, *state.shape))}
            Qs = sess.run(mainQN.output, feed_dict=feed)
            action = np.argmax(Qs)
            
            # Take action, get new state and reward
            next_state, reward, done, _ = env.step(action)
            
            if done:
                t = test_max_steps
                env.reset()
                # Take one random step to get the pole and cart moving
                state, reward, done, _ = env.step(env.action_space.sample())

            else:
                state = next_state
                t += 1
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/cartpole.ckpt
# [2017-09-12 00:19:12,056] Restoring parameters from checkpoints/cartpole.ckpt

# %%
env.close()

# %% [markdown]
# ## Extending this
#
# So, Cart-Pole is a pretty simple game. However, the same model can be used to train an agent to play something much more complicated like Pong or Space Invaders. Instead of a state like we're using here though, you'd want to use convolutional layers to get the state from the screen images.
#
# ![Deep Q-Learning Atari](assets/atari-network.png)
#
# I'll leave it as a challenge for you to use deep Q-learning to train an agent to play Atari games. Here's the original paper which will get you started: http://www.davidqiu.com:8888/research/nature14236.pdf.
